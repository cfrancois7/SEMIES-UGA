# %% [markdown]
# # Generate embeddings to get the main topic

# %% [markdown]
# In this section, we see:
# - how to extract the embeddings from one idea.
# - Reduce the dimensionality of the embeddings to visualize the relative positions of idea.
# - Create clusters from closed embeddings to propose the main topics.
# - discuss the limit of one such approach and the perspective.

# %% [markdown]
# ## Extract the embeddings with STS LLM model

# %% [markdown]
# First, download from HuggingFace Hub one similarity sentence model. This kind of model are trained to keep closed in the embedding space the sentences that are similar in meaning. For example, "I love you" and "I adore you" are similar sentences. The model will output a vector for each sentence, and the closer the vectors are, the more similar the sentences are.
#
# We're manipulating french sentences. We can try two different model:
# - [LaBSE]()
# - [intfloat/multilingual-e5-large-instruct](https://huggingface.co/intfloat/multilingual-e5-large-instruct)
#
# The e5 model seems to be better according to [HuggingFace MBET leaderboard](https://huggingface.co/spaces/mteb/leaderboard)

# %% [markdown]
# **Observations:**
# - the closed embeddings seems to be closed in meaning in the 2D space.
#
# It is the expected behavior as the LaBSE model, and the Sentence Similarity model, are trained to produce embeddings that are close in the vector space for similar sentences.
# The challenge is just to train the model to the corpus of text that corresponding to our field. For instance, French about daily subject.

# %% [markdown]
# ## Visualize and cluster the embeddings of thousand item : the challenge

# %% [markdown]
# See below the result of the LLM extractions of the [contributions of the n°163 question of the Grand Débat National 2019](https://huggingface.co/datasets/perspectiva-solution/embeddings-gdn-question-163). Each extraction is related to the contribution Id. The orginal contribution can be found in [Perspectiva HuggingFace Hub](https://huggingface.co/datasets/perspectiva-solution/contributions-gdn-question-163).
#
# The dataset contains:
# - the items by contribution Id
# - the embeddings in 1024 dimension
# - the UMAP reduced embedding in 20 dimension to cluster
# - the UMAP reduced embedding in 2 dimension to plot
# - the current proposed cluster Id.
# - the title of the cluster
#
# The value `-1` for cluster Id means the idea is related to no cluster. The embedding is too fare or too isolated from neighbors to be part of one cluster.
#
# Regarding the methodology, the title of the cluster what generated by LLM. Around 20 to 100 items are taken from one cluster, and we ask one LLM to make one title. The items are selected to be representative of the diversity of the cluster (and not the mean or the centroid).
# We does not describe the script as it is quite straightforward.

# %% [markdown]
# ### The 2D scatter plot is not enough to understand the relative importance of the main items.

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("perspectiva-solution/embeddings-gdn-question-163")['train']

# %%
ds[0]
# Out:
# {'contribution_id': 39494,
#  'text': 'arrêter de préférer les classes moyennes à la dépense des riches et des bénéficiaires du système',
#  'embeddings_1024': [-0.24221692979335785,
#   -0.5539478063583374,
#   -0.42729660868644714,
#   -0.7129496932029724,
#   0.01377530861645937,
#   0.17497481405735016,
#   0.051590561866760254,
#   0.10872132331132889,
#   0.13213038444519043,
#   -0.10053029656410217,
#   0.26859843730926514,
#   0.26942598819732666,
#   -0.18908816576004028,
#   -0.19428260624408722,
#   -0.34493887424468994,
#   -0.3137947618961334,
#   0.034439817070961,
#   -0.17854736745357513,
#   0.1654207855463028,
#   0.0932399332523346,
#   -0.16515523195266724,
#   -0.7113691568374634,
#   0.20178963243961334,
#   -0.19099177420139313,
#   -0.1614750474691391,
#   -0.4192849099636078,
#   -0.1285392940044403,
#   0.15004846453666687,
#   -0.41795614361763,
#   0.2844484746456146,
#   0.20360925793647766,
#   0.06876041740179062,
#   -0.25631093978881836,
#   0.11571101099252701,
#   -0.17549291253089905,
#   -0.034396424889564514,
#   -0.35738810896873474,
#   0.1838407814502716,
#   0.18197160959243774,
#   0.12348871678113937,
#   -0.044256702065467834,
#   -0.056453898549079895,
#   0.1487312912940979,
#   0.6541621088981628,
#   0.18454115092754364,
#   -0.29924276471138,
#   0.3174275755882263,
#   0.07045072317123413,
#   -0.1331140398979187,
#   0.3270423710346222,
#   -0.28441524505615234,
#   -0.1072096973657608,
#   0.0364496149122715,
#   0.3780015707015991,
#   0.1333196461200714,
#   0.6328007578849792,
#   0.22127728164196014,
#   0.004377154633402824,
#   -0.15591412782669067,
#   0.15635946393013,
#   0.7627100348472595,
#   0.038829267024993896,
#   0.15924471616744995,
#   0.16714154183864594,
#   -0.020768843591213226,
#   -0.028396913781762123,
#   0.33539193868637085,
#   0.13597506284713745,
#   0.10861099511384964,
#   0.3187556862831116,
#   0.16402342915534973,
#   -0.27375704050064087,
#   -0.2602199614048004,
#   -0.0008433258626610041,
#   -0.29216012358665466,
#   0.01934497430920601,
#   -0.028852198272943497,
#   0.38899320363998413,
#   -0.011206190101802349,
#   0.5553572773933411,
#   0.03503188118338585,
#   0.054407212883234024,
#   0.09449169784784317,
#   0.03474787622690201,
#   -0.03601201996207237,
#   -0.0846644714474678,
#   0.326368510723114,
#   0.09091082960367203,
#   0.7743093371391296,
#   -0.0445493720471859,
#   -0.1445942372083664,
#   -0.4263087511062622,
#   0.009687138721346855,
#   0.42846378684043884,
#   0.1878044754266739,
#   -0.14830633997917175,
#   -0.14942492544651031,
#   -0.39039352536201477,
#   0.12019717693328857,
#   0.34074917435646057,
#   -0.1812175214290619,
#   -0.23098421096801758,
#   -0.28779324889183044,
#   -0.6111789345741272,
#   -0.050425831228494644,
#   -0.06240016222000122,
#   0.4083169400691986,
#   -0.04190180078148842,
#   0.22044460475444794,
#   0.4897353947162628,
#   0.027241382747888565,
#   0.2116725742816925,
#   0.06223434954881668,
#   -0.23842062056064606,
#   0.25785505771636963,
#   0.3775336444377899,
#   0.003969040233641863,
#   -0.3901628851890564,
#   0.010269246064126492,
#   0.061552438884973526,
#   -0.10097405314445496,
#   0.12419050186872482,
#   0.5042905807495117,
#   -0.35492146015167236,
#   0.1891186237335205,
#   -0.2859833836555481,
#   0.3225093185901642,
#   0.5411481857299805,
#   0.2573050260543823,
#   0.34300169348716736,
#   0.3359490633010864,
#   0.11213596910238266,
#   0.3461655080318451,
#   0.028223488479852676,
#   0.0025908665265887976,
#   -0.19170185923576355,
#   -0.16314688324928284,
#   0.03737219423055649,
#   0.0030272735748440027,
#   0.6069082617759705,
#   0.3573899269104004,
#   0.2261691838502884,
#   -0.22671577334403992,
#   -0.1609262228012085,
#   -0.06944399327039719,
#   -0.5781436562538147,
#   0.2619135081768036,
#   0.13554681837558746,
#   0.13390162587165833,
#   -0.35560500621795654,
#   -0.2922533452510834,
#   -0.05802761763334274,
#   -0.4085863530635834,
#   0.3696070909500122,
#   -0.2568477988243103,
#   -0.45749133825302124,
#   -0.2329958826303482,
#   -0.03786969184875488,
#   0.21473854780197144,
#   -0.0597541481256485,
#   -0.06656383723020554,
#   -0.4471513330936432,
#   0.8607731461524963,
#   0.18201589584350586,
#   0.09979239106178284,
#   0.17601212859153748,
#   0.2758620083332062,
#   -0.022174695506691933,
#   0.4334951937198639,
#   -0.24281488358974457,
#   0.2054363191127777,
#   0.09839236736297607,
#   0.3244742751121521,
#   -0.016185157001018524,
#   0.1337926983833313,
#   -0.08188481628894806,
#   0.470794677734375,
#   -0.0983491837978363,
#   0.42554497718811035,
#   -0.3109840750694275,
#   0.1486230045557022,
#   0.58723384141922,
#   0.4827900528907776,
#   0.0017334653530269861,
#   -0.9608050584793091,
#   -0.051199618726968765,
#   -0.435955673456192,
#   0.11054957658052444,
#   -0.5259479284286499,
#   0.4637477695941925,
#   0.24073274433612823,
#   0.0781991183757782,
#   0.5042828321456909,
#   0.5940989255905151,
#   -0.37644457817077637,
#   -0.14887864887714386,
#   -0.33315059542655945,
#   0.21526601910591125,
#   0.09455788135528564,
#   -0.9074164628982544,
#   -0.5408675074577332,
#   0.09337817877531052,
#   0.20227473974227905,
#   -0.4972771406173706,
#   0.019030213356018066,
#   -0.2477782517671585,
#   0.16821986436843872,
#   0.07910851389169693,
#   0.46964898705482483,
#   0.2029588520526886,
#   0.3317466378211975,
#   -0.3369334936141968,
#   0.04714098945260048,
#   -0.003529944457113743,
#   -0.07756315916776657,
#   0.11521971225738525,
#   -0.06399406492710114,
#   0.039780959486961365,
#   0.32617634534835815,
#   0.13699674606323242,
#   -0.2523956894874573,
#   0.3815954625606537,
#   0.011329260654747486,
#   0.08216802030801773,
#   0.20427890121936798,
#   -0.03050387278199196,
#   -0.04521709680557251,
#   0.1721768081188202,
#   0.27273932099342346,
#   0.2229892611503601,
#   0.10509129613637924,
#   0.13917072117328644,
#   0.06814184784889221,
#   -0.09735388308763504,
#   -0.2488744556903839,
#   0.012781251221895218,
#   0.034361593425273895,
#   0.21930836141109467,
#   -0.24379462003707886,
#   0.08367448300123215,
#   -0.20891104638576508,
#   0.10573884844779968,
#   0.252234548330307,
#   -0.1808893233537674,
#   -0.3205547332763672,
#   -0.12742355465888977,
#   -0.021041441708803177,
#   -0.3266693651676178,
#   -0.37571337819099426,
#   -0.41283664107322693,
#   -0.2966929078102112,
#   -0.01532574463635683,
#   0.07287458330392838,
#   -0.165376216173172,
#   -0.11666002869606018,
#   -0.2586553394794464,
#   0.6732662320137024,
#   -0.2606784701347351,
#   0.35229265689849854,
#   0.4840323030948639,
#   -0.016888834536075592,
#   -0.05590971186757088,
#   -0.30227264761924744,
#   -0.13631585240364075,
#   0.11104699224233627,
#   -0.016158444806933403,
#   0.23594127595424652,
#   -0.002933760406449437,
#   -0.13560976088047028,
#   0.6049730181694031,
#   -0.16863341629505157,
#   0.15393707156181335,
#   -0.09225112944841385,
#   -0.06321975588798523,
#   0.4130556285381317,
#   -0.4400731027126312,
#   -0.038147542625665665,
#   -0.10474526882171631,
#   0.21366477012634277,
#   0.08119353652000427,
#   0.40407073497772217,
#   0.24138668179512024,
#   0.2197602540254593,
#   -0.12058958411216736,
#   -0.6627606749534607,
#   0.3136039078235626,
#   0.05955429747700691,
#   0.2389669418334961,
#   -0.3754584491252899,
#   0.011607366614043713,
#   -0.07872053980827332,
#   0.19215498864650726,
#   -0.3065612018108368,
#   0.16482855379581451,
#   0.21905085444450378,
#   0.37147146463394165,
#   -0.03750462085008621,
#   -0.28614342212677,
#   0.2672446072101593,
#   -0.07968758046627045,
#   -0.002007385017350316,
#   -0.213882714509964,
#   0.6117579936981201,
#   0.02239110879600048,
#   -0.04975143447518349,
#   0.20702432096004486,
#   -0.3780611753463745,
#   -0.3146677613258362,
#   0.12414778769016266,
#   -0.27376630902290344,
#   -0.593267560005188,
#   -0.07290312647819519,
#   -0.06909634172916412,
#   0.3466005325317383,
#   -0.7096407413482666,
#   0.4270530939102173,
#   0.3905889391899109,
#   -0.30947211384773254,
#   -0.29511716961860657,
#   -0.3037031888961792,
#   0.07656995207071304,
#   0.5105682611465454,
#   -0.080651193857193,
#   0.391634076833725,
#   0.03078065998852253,
#   -0.1380877047777176,
#   0.29599010944366455,
#   0.23737256228923798,
#   -0.1271228790283203,
#   0.382398396730423,
#   -0.1785145252943039,
#   0.01113502774387598,
#   -0.08557360619306564,
#   -0.290092796087265,
#   -0.06756629794836044,
#   0.22567659616470337,
#   -0.2683878540992737,
#   0.1109515130519867,
#   -0.13869830965995789,
#   0.7122098803520203,
#   0.20557962357997894,
#   0.42930322885513306,
#   0.15746092796325684,
#   0.047171492129564285,
#   -0.3749028444290161,
#   -0.14461252093315125,
#   -0.29180166125297546,
#   -0.03513873741030693,
#   -0.176513209939003,
#   -0.1686958372592926,
#   0.3661474287509918,
#   0.10510345548391342,
#   -0.08946936577558517,
#   -0.35543644428253174,
#   -0.4962170422077179,
#   0.07958552986383438,
#   0.14295071363449097,
#   0.3194407820701599,
#   0.1716359257698059,
#   0.4995790123939514,
#   -0.06043504178524017,
#   -0.2576883137226105,
#   -0.1472141146659851,
#   0.2800399959087372,
#   0.44560274481773376,
#   0.0400899201631546,
#   -0.29941949248313904,
#   0.09003268927335739,
#   0.09839211404323578,
#   -0.1594451367855072,
#   -0.3061315417289734,
#   0.18921363353729248,
#   -0.020578324794769287,
#   0.10003484785556793,
#   -0.18185372650623322,
#   -0.2865082919597626,
#   -0.2898181676864624,
#   -0.5147713422775269,
#   -0.010614433325827122,
#   0.11671590805053711,
#   0.0407814159989357,
#   -0.08813480287790298,
#   -0.07138742506504059,
#   -0.0672188326716423,
#   -0.2562919855117798,
#   -0.1810939908027649,
#   -0.07472468912601471,
#   -0.2853471040725708,
#   0.22070877254009247,
#   -0.24470803141593933,
#   0.06637927889823914,
#   0.1754438877105713,
#   0.15590402483940125,
#   -0.09299471974372864,
#   0.2815591096878052,
#   -0.0907297357916832,
#   -0.016884498298168182,
#   -0.2967170476913452,
#   0.2207849621772766,
#   -0.1885278820991516,
#   -0.3897591829299927,
#   0.254097580909729,
#   0.20918434858322144,
#   -0.1468595266342163,
#   -0.13115137815475464,
#   0.3347472548484802,
#   0.21908412873744965,
#   -0.41820982098579407,
#   0.017319003120064735,
#   -0.023196186870336533,
#   0.0745435431599617,
#   0.278694748878479,
#   -0.007603044155985117,
#   -0.4922773540019989,
#   -0.028891917318105698,
#   -0.07503914088010788,
#   0.18058685958385468,
#   0.2313556671142578,
#   -0.051688503473997116,
#   0.42871907353401184,
#   -0.337893009185791,
#   0.1373278796672821,
#   0.36937543749809265,
#   -0.17230619490146637,
#   -0.2568366229534149,
#   -0.6268168687820435,
#   0.38325783610343933,
#   0.16996720433235168,
#   0.08423924446105957,
#   0.10472825914621353,
#   0.584071159362793,
#   0.309397429227829,
#   -0.0802830159664154,
#   -0.018958598375320435,
#   -0.48334816098213196,
#   0.13473081588745117,
#   -0.03937937691807747,
#   0.29780951142311096,
#   -0.10577528923749924,
#   0.016560539603233337,
#   -0.008655089884996414,
#   0.14535187184810638,
#   0.1293441653251648,
#   0.3166090250015259,
#   -0.2118990123271942,
#   0.7211391925811768,
#   0.5516960024833679,
#   0.1926567107439041,
#   -0.03855720907449722,
#   -0.3674004375934601,
#   0.23740601539611816,
#   0.29640308022499084,
#   -0.17108409106731415,
#   -0.4400021433830261,
#   -0.28847163915634155,
#   0.15297532081604004,
#   0.017285289242863655,
#   0.1182759627699852,
#   0.0034341018181294203,
#   0.007173384074121714,
#   0.2619955539703369,
#   0.46331650018692017,
#   0.16958054900169373,
#   0.24965640902519226,
#   -0.1425965428352356,
#   -0.005112061742693186,
#   0.07243502140045166,
#   -0.1344759613275528,
#   0.9088408946990967,
#   -0.01306312158703804,
#   -0.35202157497406006,
#   -0.12746043503284454,
#   -0.16993951797485352,
#   0.1803215742111206,
#   0.032112572342157364,
#   0.219527930021286,
#   0.6680548191070557,
#   -0.3857356011867523,
#   -0.06843128800392151,
#   0.0600823350250721,
#   -0.1678246408700943,
#   -0.14060615003108978,
#   -0.08688119798898697,
#   0.02332659810781479,
#   -0.06153790280222893,
#   0.04465710371732712,
#   0.2772131562232971,
#   -0.16372106969356537,
#   0.3678148090839386,
#   -0.08832725137472153,
#   -0.10207533836364746,
#   -0.4666600823402405,
#   0.34500041604042053,
#   -0.29253411293029785,
#   -0.08465418219566345,
#   -0.3822842836380005,
#   -0.18963751196861267,
#   0.023056823760271072,
#   -0.1607181876897812,
#   -0.11396922171115875,
#   0.3879372179508209,
#   -0.11149462312459946,
#   0.2682582139968872,
#   0.3981674015522003,
#   -0.13075821101665497,
#   0.2688050866127014,
#   0.2830899953842163,
#   0.2116023153066635,
#   0.14632131159305573,
#   -0.0920926034450531,
#   0.23074626922607422,
#   0.3213839828968048,
#   0.7261075377464294,
#   0.12764345109462738,
#   0.3755154609680176,
#   0.02488579973578453,
#   -0.14756707847118378,
#   0.31313633918762207,
#   0.19911469519138336,
#   0.12685558199882507,
#   0.2627071142196655,
#   -0.1973291039466858,
#   0.005599609576165676,
#   0.2910037040710449,
#   -0.39154624938964844,
#   0.2525062561035156,
#   0.5324155688285828,
#   -0.350186824798584,
#   -0.49209779500961304,
#   0.09956192225217819,
#   0.4076349437236786,
#   0.5165305733680725,
#   -0.07354547083377838,
#   0.19557061791419983,
#   -0.7796900272369385,
#   -0.21116286516189575,
#   0.28776878118515015,
#   0.011771125718951225,
#   0.43727707862854004,
#   -0.0955948531627655,
#   -0.1552107036113739,
#   0.31787145137786865,
#   -0.3961585760116577,
#   -0.3206530809402466,
#   -0.013109053485095501,
#   -0.09177375584840775,
#   -0.4318310022354126,
#   -0.4068751633167267,
#   0.23101885616779327,
#   0.24078959226608276,
#   0.41927602887153625,
#   -0.38458144664764404,
#   0.0439843125641346,
#   0.17102394998073578,
#   -0.14828599989414215,
#   0.04300123453140259,
#   -0.32484936714172363,
#   -0.32344141602516174,
#   -0.11817914992570877,
#   0.3861909806728363,
#   0.27881428599357605,
#   -0.3958708941936493,
#   0.2854013442993164,
#   0.4675385653972626,
#   0.8487913608551025,
#   0.12139209359884262,
#   -0.0065148272551596165,
#   0.3149941861629486,
#   -0.14085012674331665,
#   -0.45650801062583923,
#   -0.1682942509651184,
#   0.11169227212667465,
#   -0.009027989581227303,
#   0.7686015367507935,
#   0.03030122071504593,
#   0.13562454283237457,
#   -0.27921438217163086,
#   -0.0259394571185112,
#   0.40696266293525696,
#   0.4039522409439087,
#   -0.8354732990264893,
#   0.07496002316474915,
#   -0.03215734660625458,
#   0.18094193935394287,
#   0.2769519090652466,
#   0.3436450958251953,
#   -0.1143786609172821,
#   -0.01934424601495266,
#   -0.21578706800937653,
#   -0.18320803344249725,
#   -0.216585174202919,
#   -0.31590646505355835,
#   0.3423866033554077,
#   -0.18319834768772125,
#   -0.023846885189414024,
#   0.4002714157104492,
#   0.2948288321495056,
#   0.17680668830871582,
#   0.3784025013446808,
#   0.08423702418804169,
#   -0.45387351512908936,
#   0.5709433555603027,
#   -0.007900554686784744,
#   -0.03968024253845215,
#   0.49581390619277954,
#   0.362751841545105,
#   -0.03417827561497688,
#   0.11011818051338196,
#   -0.12476541101932526,
#   -0.001265284139662981,
#   0.2281072437763214,
#   -0.08268428593873978,
#   -0.295733779668808,
#   0.46325990557670593,
#   0.21878549456596375,
#   0.4843672513961792,
#   0.05133162438869476,
#   0.3362349569797516,
#   -0.06872286647558212,
#   -0.285293310880661,
#   -0.3723113536834717,
#   -0.597174882888794,
#   -0.030728615820407867,
#   0.2631557285785675,
#   -0.5288950204849243,
#   -0.38574355840682983,
#   -0.15172046422958374,
#   0.03545098751783371,
#   0.3641791045665741,
#   0.11696204543113708,
#   0.5498822331428528,
#   0.08889341354370117,
#   0.2703397572040558,
#   -0.17356103658676147,
#   0.1587720364332199,
#   -0.2107372283935547,
#   -0.042733777314424515,
#   0.08039790391921997,
#   0.3589606285095215,
#   -0.0635223314166069,
#   -0.13288655877113342,
#   -0.042006492614746094,
#   0.3373652994632721,
#   0.3323545753955841,
#   0.3264094889163971,
#   0.019846566021442413,
#   0.3864770531654358,
#   0.09158419072628021,
#   0.026193980127573013,
#   -0.03748287633061409,
#   -0.12696242332458496,
#   -0.2820453345775604,
#   -0.27705347537994385,
#   -0.13983091711997986,
#   -0.3451917767524719,
#   0.5509504079818726,
#   0.23753765225410461,
#   0.00873678270727396,
#   -0.13836519420146942,
#   -0.11017495393753052,
#   -0.09462002664804459,
#   0.35503089427948,
#   0.023935215547680855,
#   0.007086168508976698,
#   -0.21813108026981354,
#   -0.1299475133419037,
#   0.1175730749964714,
#   0.4260627031326294,
#   -0.07586125284433365,
#   -0.13465622067451477,
#   0.21534092724323273,
#   -0.495572030544281,
#   0.3985932171344757,
#   0.1189579963684082,
#   -0.0888763815164566,
#   -0.4718899130821228,
#   -0.287528932094574,
#   -0.2737657129764557,
#   -0.2627694308757782,
#   -0.18341118097305298,
#   -0.4766557514667511,
#   -0.500148594379425,
#   -0.45072731375694275,
#   -0.3110732436180115,
#   0.20113176107406616,
#   -0.6162564158439636,
#   0.28150123357772827,
#   0.10045516490936279,
#   0.01789819449186325,
#   -0.02505294233560562,
#   0.5670135021209717,
#   0.030382808297872543,
#   -0.4524935483932495,
#   0.22287903726100922,
#   0.288808673620224,
#   0.3504065275192261,
#   -0.384251207113266,
#   -0.13220345973968506,
#   0.20201629400253296,
#   -0.12429992109537125,
#   0.45383018255233765,
#   0.10390399396419525,
#   -0.004564030095934868,
#   0.0266287662088871,
#   -0.6603893041610718,
#   -0.07509534806013107,
#   0.48076331615448,
#   -0.2685035765171051,
#   0.9989981055259705,
#   -0.3460765480995178,
#   -0.1996239423751831,
#   -0.08129880577325821,
#   0.24511878192424774,
#   -0.3752444088459015,
#   0.401806503534317,
#   -0.17844480276107788,
#   0.1716320663690567,
#   0.2410772144794464,
#   -0.1372164636850357,
#   0.005709165241569281,
#   -0.21841126680374146,
#   -0.054395902901887894,
#   0.12206375598907471,
#   -0.03465515375137329,
#   -0.26570725440979004,
#   0.28990408778190613,
#   -0.07026740163564682,
#   -0.019237015396356583,
#   -0.0665193423628807,
#   0.45548132061958313,
#   -0.016339033842086792,
#   0.18040865659713745,
#   0.40180790424346924,
#   -0.17295067012310028,
#   -0.05027434602379799,
#   0.6364663243293762,
#   -0.48379644751548767,
#   -0.09152892231941223,
#   0.011638464406132698,
#   -0.38996484875679016,
#   0.44131866097450256,
#   -0.08170828968286514,
#   0.22841119766235352,
#   0.09506145864725113,
#   -0.39364540576934814,
#   -0.07547733187675476,
#   0.04672140255570412,
#   -0.10305856168270111,
#   -0.14296148717403412,
#   0.9297305345535278,
#   0.03880612179636955,
#   -0.20126576721668243,
#   0.22375236451625824,
#   0.051047250628471375,
#   0.07386276870965958,
#   0.0049834358505904675,
#   -0.4733681082725525,
#   -0.7155253291130066,
#   0.32090193033218384,
#   -0.0321129634976387,
#   -0.2879442572593689,
#   -0.3564413785934448,
#   0.4230586886405945,
#   -0.3784736394882202,
#   -0.011103926226496696,
#   -0.09241613000631332,
#   -0.2081650346517563,
#   0.1637466549873352,
#   0.4128061532974243,
#   0.21831586956977844,
#   -0.2752462923526764,
#   0.20222724974155426,
#   -0.027219517156481743,
#   -0.06421661376953125,
#   0.45050907135009766,
#   -0.1870485544204712,
#   0.19074764847755432,
#   0.2781665325164795,
#   -0.0037875687703490257,
#   -0.11025499552488327,
#   0.14506027102470398,
#   -0.3435249924659729,
#   -0.18011033535003662,
#   -0.013696683570742607,
#   -0.12568487226963043,
#   0.28959718346595764,
#   -0.280171275138855,
#   0.02871926687657833,
#   0.15304340422153473,
#   -0.10398753732442856,
#   -0.17596855759620667,
#   -0.2880982756614685,
#   0.025675557553768158,
#   0.11589023470878601,
#   0.1297447383403778,
#   0.40898215770721436,
#   -0.05906619131565094,
#   -0.1681600660085678,
#   0.08246258646249771,
#   -0.38442957401275635,
#   -0.20727714896202087,
#   0.10910087078809738,
#   -0.43332237005233765,
#   -0.06483746320009232,
#   0.07669717073440552,
#   0.17968517541885376,
#   -0.4768718481063843,
#   0.10234766453504562,
#   0.05687258765101433,
#   0.2156018614768982,
#   -0.3032570779323578,
#   0.047046348452568054,
#   0.027931086719036102,
#   -0.22186607122421265,
#   0.16916269063949585,
#   0.039613932371139526,
#   -0.1629323810338974,
#   -0.2606739401817322,
#   -0.002123375656083226,
#   0.09252704679965973,
#   0.1735570728778839,
#   -0.19369293749332428,
#   0.25528696179389954,
#   0.47242292761802673,
#   0.2512367367744446,
#   -0.6122785210609436,
#   0.12698444724082947,
#   -0.16971422731876373,
#   -0.014294404536485672,
#   -0.3239487111568451,
#   -0.4850747883319855,
#   0.2386035919189453,
#   0.14432574808597565,
#   -0.06738930195569992,
#   -0.02860414981842041,
#   0.8356860280036926,
#   0.8529583811759949,
#   -0.03834819421172142,
#   0.008060809224843979,
#   0.078220434486866,
#   -0.278561532497406,
#   0.09187706559896469,
#   -0.07865841686725616,
#   0.08826655894517899,
#   -0.28700679540634155,
#   -0.06705246865749359,
#   -0.14641234278678894,
#   0.3952488601207733,
#   -0.1681165099143982,
#   -0.054925065487623215,
#   0.1244896650314331,
#   -0.11133530735969543,
#   -0.23656238615512848,
#   0.04936564713716507,
#   -0.30547064542770386,
#   -0.4160289764404297,
#   -0.052874233573675156,
#   -0.2806515693664551,
#   0.23245769739151,
#   0.2788807451725006,
#   0.06423905491828918,
#   0.2969282567501068,
#   0.2555616796016693,
#   -0.23630046844482422,
#   -0.5399148464202881,
#   0.19158536195755005,
#   -0.22966384887695312,
#   0.12714652717113495,
#   -0.10079961270093918,
#   0.03324392810463905,
#   -0.11127054691314697,
#   0.35325872898101807,
#   0.24631768465042114,
#   0.05251847207546234,
#   0.019507765769958496,
#   0.30470898747444153,
#   -0.44555914402008057,
#   -0.10343936830759048,
#   0.18519407510757446,
#   0.1290459781885147,
#   -0.036352790892124176,
#   -0.1781792938709259,
#   -0.5400465726852417,
#   -0.07545439153909683,
#   0.17299000918865204,
#   -0.16528506577014923,
#   -0.4001256823539734,
#   -0.019413283094763756,
#   0.2008618265390396,
#   0.05311359465122223,
#   -0.0896792858839035,
#   0.088323213160038,
#   -0.584028959274292,
#   0.3902948796749115,
#   0.3182021677494049,
#   -0.025717737153172493,
#   -0.06680934131145477,
#   0.21014158427715302,
#   0.06804242730140686,
#   -0.14009633660316467,
#   -0.041057322174310684,
#   0.5234654545783997,
#   0.5470805764198303,
#   0.15779264271259308,
#   0.0008467455045320094,
#   0.4496704339981079,
#   -0.06672276556491852,
#   0.45101943612098694,
#   0.1257396638393402,
#   -0.13373422622680664,
#   -0.018653400242328644,
#   -0.2545989751815796,
#   0.13152091205120087,
#   -0.10331518203020096,
#   -0.007935397326946259,
#   0.07090005278587341,
#   -0.3465322256088257,
#   0.5447087287902832,
#   -0.19964858889579773,
#   0.17100538313388824,
#   0.08856281638145447,
#   -0.2504163682460785,
#   0.12439145147800446,
#   0.4278913736343384,
#   -0.11932492256164551,
#   -0.18392470479011536,
#   -0.0915931910276413,
#   -0.1819649189710617,
#   0.0832795575261116,
#   0.39749452471733093,
#   -0.23047664761543274,
#   0.02093380317091942,
#   0.17889076471328735,
#   0.20605993270874023,
#   0.6213557720184326,
#   0.06478796899318695,
#   -0.2012644112110138,
#   0.38823312520980835,
#   0.13428790867328644,
#   -0.2536875009536743,
#   0.19702361524105072,
#   -0.2893533408641815,
#   0.3324414789676666,
#   0.363638699054718,
#   0.4776462912559509,
#   0.24678534269332886,
#   0.14904431998729706,
#   -0.14296923577785492,
#   -0.12587788701057434,
#   0.19679254293441772,
#   -0.13219666481018066,
#   0.13494285941123962,
#   0.22126001119613647,
#   0.13104969263076782,
#   0.22145086526870728,
#   0.1261051595211029,
#   -0.48315197229385376,
#   -0.40258800983428955,
#   0.07139411568641663,
#   -0.044899892061948776,
#   -0.026672102510929108,
#   0.17060208320617676,
#   0.42346835136413574,
#   0.036001820117235184,
#   -0.12035373598337173,
#   -0.17269819974899292,
#   0.3131895661354065,
#   0.049679771065711975,
#   0.3157197833061218,
#   0.5607486367225647,
#   -0.06251062452793121,
#   -0.3601705729961395,
#   -0.7018567323684692,
#   0.08645273745059967,
#   -0.3151403069496155,
#   -0.30306458473205566,
#   0.2173287719488144,
#   0.2139873057603836,
#   0.47960165143013,
#   0.011139716021716595,
#   0.3118824362754822,
#   0.1724923700094223,
#   0.2511945962905884,
#   -0.09605909138917923,
#   0.4080864489078522,
#   0.22178618609905243,
#   -0.008410866372287273,
#   0.38674914836883545,
#   -0.054156344383955,
#   0.25392329692840576,
#   0.28545260429382324,
#   0.14348167181015015,
#   0.5533502697944641,
#   -0.22272706031799316,
#   -0.33518165349960327,
#   0.033525485545396805,
#   -0.18480484187602997,
#   -0.10698460042476654,
#   -0.07275886088609695,
#   0.05079572647809982,
#   ...],
#  'cluster_id': -1,
#  'umap_20': [0.021367179229855537,
#   10.011727333068848,
#   1.782883882522583,
#   0.394584983587265,
#   8.41489315032959,
#   4.643890380859375,
#   5.619585037231445,
#   7.64059591293335,
#   8.821148872375488,
#   8.84489631652832,
#   1.1344764232635498,
#   2.604379653930664,
#   3.2882943153381348,
#   8.549009323120117,
#   8.974225044250488,
#   4.323915004730225,
#   2.574094295501709,
#   1.1758328676223755,
#   0.4659139811992645,
#   2.4935638904571533],
#  'umap_2': [15.631861686706543, 1.3952943086624146],
#  'cluster_title': 'N/A'}

# %% [markdown]
# **Observations:**
# - When we look at the embedding of many items, we can see some clusters, but it is clearly not clear how much the density of the clusters is.
# - In fact, one very concentrated cluster is less visible than one cluster that spread a little. The perception give more importance to the surface.

# %% [markdown]
# ### Current way to communicate: two plots difficult to associate.

# %%
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt

# %%
df = ds.to_pandas()

# %%
dict_abundance_idea = df.groupby("cluster_title")["contribution_id"].nunique()
nb_contrib = df["contribution_id"].nunique()
dict_abundance_idea.sort_values()
n_clusters = df.loc[df.cluster_id!=-1, "cluster_id"].nunique()

from itertools import combinations
from tqdm import tqdm

all_combinations = tuple(combinations(range(n_clusters), 2))

cooccurence_matrix = np.zeros((n_clusters, n_clusters))

for _, contrib_df in tqdm(df.groupby("contribution_id")):
    contrib_df = contrib_df[contrib_df["cluster_id"]!= -1]
    for i, j in combinations(sorted(contrib_df["cluster_id"].unique()), 2):
        cooccurence_matrix[i, j] += 1
# Out:
# 100%|██████████| 52200/52200 [00:13<00:00, 3784.45it/s]

# %%
cluster_occurence = df.cluster_id[df.cluster_id != -1].value_counts().sort_index()
marginal_occurence = np.ones_like(cooccurence_matrix, dtype=int)

for i, j in combinations(range(n_clusters), 2):
    marginal_occurence[i, j] = cluster_occurence.values[i] + cluster_occurence.values[j]

fig, axes = plt.subplots(1, 2, figsize=(8, 4))
axes[0].imshow(cooccurence_matrix)
axes[0].set_title("Raw co-occurence")
axes[1].imshow(cooccurence_matrix / marginal_occurence)
axes[1].set_title("Co-occurence normalized by cluster counts")
# Out:
# Text(0.5, 1.0, 'Co-occurence normalized by cluster counts')

# %%
from scipy.cluster.hierarchy import (
    linkage, leaves_list, optimal_leaf_ordering, dendrogram, to_tree
)
from scipy.spatial.distance import pdist, squareform


subdf = df.loc[df.cluster_id != -1,["cluster_id", "cluster_title"]].drop_duplicates()
mapping = {k : subdf.loc[subdf.cluster_id == k, "cluster_title"].values[0] for k in range(n_clusters)}

normalized_mat = cooccurence_matrix / marginal_occurence
sym_mat = normalized_mat + normalized_mat.T

Z = linkage(1 - squareform(sym_mat), method="ward")
fig, ax = plt.subplots(figsize=(5, 30))
dend = dendrogram(
    Z,
    leaf_rotation=0,
    orientation="right",
    count_sort="descending",
    ax=ax,
    labels=list(mapping.values()),
    color_threshold=1.01

)
plt.show()
leaves = dend["leaves"]
mesh = np.ix_(leaves[::-1], leaves[::-1])
sorted_mat = sym_mat[mesh]

plt.imshow(
    sorted_mat,
    cmap="viridis"
)

# %%
subdf = df.loc[df.cluster_id != -1,["cluster_id", "cluster_title"]].drop_duplicates()
cluster_title_map = {k : subdf.loc[subdf.cluster_id == k, "cluster_title"].values[0] for k in range(n_clusters)}

# %%
def generate_color_palette():
    cmap = plt.colormaps['tab10']  # 'tab10' or 'tab20' are great for categorical
    return [f'#{int(r*255):02x}{int(g*255):02x}{int(b*255):02x}' for r, g, b in cmap.colors]

palette = generate_color_palette()

leaves_color = dend["leaves_color_list"]
color_values = [palette[i % len(palette)] for i in range(len(np.unique(leaves_color)))]

color_mapping = dict(zip(np.unique(leaves_color), color_values))

# %%
import networkx as nx
from pyvis.network import Network

G = nx.Graph()

# Add all original observation nodes
for i, leaf in enumerate(leaves):
    G.add_node(leaf)
    G.nodes[leaf]["size"] = 30
    G.nodes[leaf]["title"] = cluster_title_map[leaf]
    G.nodes[leaf]["color"] = color_mapping[leaves_color[i]]


# Add edges from linkage matrix
for i, (a, b, dist, _) in enumerate(Z):
    node_id = n_clusters + i  # new cluster node id

    # Add a new node representing this cluster
    G.add_node(node_id)
    G.nodes[node_id]["title"] = None
    G.nodes[node_id]["size"] = 10
    G.nodes[node_id]["color"] = "lightblue"

    # Add edges to the two children (a and b)
    edge_color = dend["color_list"][i]
    G.add_edge(node_id, int(a), color=edge_color)
    G.add_edge(node_id, int(b), color=edge_color)

# %%
nt = Network("500px", "500px")
nt.from_nx(G)
nt.toggle_physics(True)
nt.show("dend.html", notebook=False)
# Out:
# dend.html

# %%
# Cut dendogram into 7 clusters

from scipy.cluster.hierarchy import fcluster


def cut_linkage(Z, n):

    distances = Z[:, 2]
    for q in np.linspace(0.9, 1, 20):
        quantile = np.quantile(distances, q)
        flat_clusters = fcluster(Z, t=quantile, criterion="distance")
        n_flat = len(np.unique(flat_clusters))
        if n_flat == n:
            return flat_clusters, quantile
    raise ValueError(f"Not cut found for {n} clusters")

cut_cluster, t = cut_linkage(Z, 7)
